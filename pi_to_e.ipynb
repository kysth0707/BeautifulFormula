# %% [markdown]
# $$\left( \frac{\frac{\frac{\frac{\frac{\frac{\frac{\frac{\frac{\pi}{\pi}}{\int_{-\frac{\pi}{\pi}}^{\frac{\pi}{\pi}}d\pi_{\pi}^{{\frac{\pi}{\pi}}}}}{\int_{-\frac{\pi}{\pi}}^{\frac{\pi}{\pi}}d\pi_{\pi_{\pi}}^{-{\frac{\pi}{\pi}}}}}{\int_{-\frac{\pi}{\pi}}^{\frac{\pi}{\pi}}d\pi_{\pi_{\pi}\pi}^{-\left( \int_{\frac{\pi}{\pi}}^{{\sum_{\pi_{\pi_{\pi_{\pi}}\pi_{\pi_{\pi}}}=\int_{\frac{\pi}{\pi}}^{\frac{\pi}{\pi}}d\pi_{\pi_{\pi_{\pi}}\pi_{\pi_{\pi}}\pi}}^{\int_{-\frac{\pi}{\pi}}^{\frac{\pi}{\pi}}\int_{-\frac{\pi}{\pi}}^{\frac{\pi}{\pi}}d\pi_{\pi_{\pi_{\pi}}\pi_{\pi_{\pi}}\pi_{\pi}}d\pi_{\pi_{\pi_{\pi}}\pi_{\pi_{\pi}}\pi_{\pi_{\pi}}}}\frac{{\int_{-\frac{\pi}{\pi}}^{\frac{\pi}{\pi}}d\pi_{\pi_{\pi}\pi_{\pi}}^{1}}^{\pi_{\pi_{\pi_{\pi}}\pi_{\pi_{\pi}}}}}{\pi_{\pi_{\pi_{\pi}}\pi_{\pi_{\pi}}}!}\sum_{\pi_{\pi_{\pi_{\pi_{\pi}}}\pi_{\pi_{\pi}}\pi_{\pi_{\pi}}}=\int_{\frac{\pi}{\pi}}^{\frac{\pi}{\pi}}d\pi_{\pi_{\pi_{\pi_{\pi}}}\pi_{\pi_{\pi_{\pi}}}\pi_{\pi_{\pi}}}}^{\int_{-\frac{\pi}{\pi}}^{\frac{\pi}{\pi}}\int_{-\frac{\pi}{\pi}}^{\frac{\pi}{\pi}}d\pi_{\pi_{\pi_{\pi_{\pi}}}\pi_{\pi_{\pi_{\pi}}}\pi_{\pi_{\pi_{\pi}}}}d\pi_{\pi_{\pi_{\pi_{\pi}}}\pi_{\pi_{\pi_{\pi}}}\pi_{\pi_{\pi_{\pi}}}\pi}}\frac{{\int_{-\frac{\pi}{\pi}}^{\frac{\pi}{\pi}}d\pi_{\pi_{\pi_{\pi}}\pi_{\pi}}^{0}}^{\pi_{\pi_{\pi_{\pi_{\pi}}}\pi_{\pi_{\pi}}\pi_{\pi_{\pi}}}}}{\pi_{\pi_{\pi_{\pi_{\pi}}}\pi_{\pi_{\pi}}\pi_{\pi_{\pi}}}!}}}\pi_{\pi_{\pi_{\pi_{\pi}}}\pi_{\pi_{\pi_{\pi}}}\pi_{\pi_{\pi_{\pi}}}\pi_{\pi}}^{-\frac{\pi}{\pi}}d\pi_{\pi_{\pi_{\pi_{\pi}}}\pi_{\pi_{\pi_{\pi}}}\pi_{\pi_{\pi_{\pi}}}\pi_{\pi}} \right) }}}{\int_{-\frac{\pi}{\pi}}^{\frac{\pi}{\pi}}d\pi_{\pi_{\pi_{\pi_{\pi}}}\pi_{\pi_{\pi_{\pi}}}\pi_{\pi_{\pi_{\pi}}}\pi_{\pi_{\pi}}}^{-\left( \int_{\frac{\pi}{\pi}}^{{\sum_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}\pi_{\pi_{\pi_{\pi}}}\pi_{\pi_{\pi_{\pi}}}\pi_{\pi_{\pi_{\pi}}}}=\int_{\frac{\pi}{\pi}}^{\frac{\pi}{\pi}}d\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}\pi_{\pi_{\pi_{\pi_{\pi}}}}\pi_{\pi_{\pi_{\pi}}}\pi_{\pi_{\pi_{\pi}}}}}^{\int_{-\frac{\pi}{\pi}}^{\frac{\pi}{\pi}}\int_{-\frac{\pi}{\pi}}^{\frac{\pi}{\pi}}d\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}\pi_{\pi_{\pi_{\pi_{\pi}}}}\pi_{\pi_{\pi_{\pi_{\pi}}}}\pi_{\pi_{\pi_{\pi}}}}d\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}\pi_{\pi_{\pi_{\pi_{\pi}}}}\pi_{\pi_{\pi_{\pi_{\pi}}}}\pi_{\pi_{\pi_{\pi_{\pi}}}}}}\frac{{\int_{-\frac{\pi}{\pi}}^{\frac{\pi}{\pi}}d\pi_{\pi_{\pi_{\pi_{\pi}}}\pi_{\pi_{\pi_{\pi}}}\pi_{\pi_{\pi_{\pi}}}\pi_{\pi_{\pi_{\pi}}}}^{[1]}}^{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}\pi_{\pi_{\pi_{\pi}}}\pi_{\pi_{\pi_{\pi}}}\pi_{\pi_{\pi_{\pi}}}}}}{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}\pi_{\pi_{\pi_{\pi}}}\pi_{\pi_{\pi_{\pi}}}\pi_{\pi_{\pi_{\pi}}}}!}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}\pi_{\pi_{\pi_{\pi_{\pi}}}}\pi_{\pi_{\pi_{\pi_{\pi}}}}\pi_{\pi_{\pi_{\pi_{\pi}}}}\pi}^{-\frac{\pi}{\pi}}d\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}\pi_{\pi_{\pi_{\pi_{\pi}}}}\pi_{\pi_{\pi_{\pi_{\pi}}}}\pi_{\pi_{\pi_{\pi_{\pi}}}}\pi} \right) }}}{\int_{-\frac{\pi}{\pi}}^{\frac{\pi}{\pi}}d\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}\pi_{\pi_{\pi_{\pi_{\pi}}}}\pi_{\pi_{\pi_{\pi_{\pi}}}}\pi_{\pi_{\pi_{\pi_{\pi}}}}\pi_{\pi}}^{-\left( \int_{\frac{\pi}{\pi}}^{{\sum_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}\pi_{\pi_{\pi_{\pi_{\pi}}}}\pi_{\pi_{\pi_{\pi_{\pi}}}}\pi_{\pi_{\pi_{\pi_{\pi}}}}\pi_{\pi_{\pi_{\pi_{\pi}}}}}=\int_{\frac{\pi}{\pi}}^{\frac{\pi}{\pi}}d\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}\pi_{\pi_{\pi_{\pi_{\pi}}}}\pi_{\pi_{\pi_{\pi_{\pi}}}}\pi_{\pi_{\pi_{\pi_{\pi}}}}\pi_{\pi_{\pi_{\pi_{\pi}}}}}}^{\int_{-\frac{\pi}{\pi}}^{\frac{\pi}{\pi}}\int_{-\frac{\pi}{\pi}}^{\frac{\pi}{\pi}}d\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}\pi_{\pi_{\pi_{\pi_{\pi}}}}\pi_{\pi_{\pi_{\pi_{\pi}}}}\pi_{\pi_{\pi_{\pi_{\pi}}}}}d\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}\pi_{\pi_{\pi_{\pi_{\pi}}}}\pi_{\pi_{\pi_{\pi_{\pi}}}}}}\frac{{\int_{-\frac{\pi}{\pi}}^{\frac{\pi}{\pi}}d\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}\pi_{\pi_{\pi_{\pi_{\pi}}}}\pi_{\pi_{\pi_{\pi_{\pi}}}}\pi_{\pi_{\pi_{\pi_{\pi}}}}\pi_{\pi_{\pi}}}^{[1]}}^{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}\pi_{\pi_{\pi_{\pi_{\pi}}}}\pi_{\pi_{\pi_{\pi_{\pi}}}}\pi_{\pi_{\pi_{\pi_{\pi}}}}\pi_{\pi_{\pi_{\pi_{\pi}}}}}}}{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}\pi_{\pi_{\pi_{\pi_{\pi}}}}\pi_{\pi_{\pi_{\pi_{\pi}}}}\pi_{\pi_{\pi_{\pi_{\pi}}}}\pi_{\pi_{\pi_{\pi_{\pi}}}}}!}\sum_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}\pi_{\pi_{\pi_{\pi_{\pi}}}}}=\int_{\frac{\pi}{\pi}}^{\frac{\pi}{\pi}}d\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}}^{\int_{-\frac{\pi}{\pi}}^{\frac{\pi}{\pi}}\int_{-\frac{\pi}{\pi}}^{\frac{\pi}{\pi}}d\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}\pi}d\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}\pi_{\pi}}}\frac{{\int_{-\frac{\pi}{\pi}}^{\frac{\pi}{\pi}}d\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}\pi_{\pi_{\pi_{\pi_{\pi}}}}\pi_{\pi_{\pi_{\pi_{\pi}}}}\pi_{\pi_{\pi_{\pi_{\pi}}}}\pi_{\pi_{\pi_{\pi}}}}^{1}}^{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}\pi_{\pi_{\pi_{\pi_{\pi}}}}}}}{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}\pi_{\pi_{\pi_{\pi_{\pi}}}}}!}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}\pi_{\pi_{\pi}}}^{-\frac{\pi}{\pi}}d\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}\pi_{\pi_{\pi}}} \right) }}}{\int_{-\frac{\pi}{\pi}}^{\frac{\pi}{\pi}}d\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}\pi_{\pi_{\pi_{\pi}}}}^{-\left( \int_{\frac{\pi}{\pi}}^{{\sum_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}=\int_{\frac{\pi}{\pi}}^{\frac{\pi}{\pi}}d\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}}^{\int_{-\frac{\pi}{\pi}}^{\frac{\pi}{\pi}}\int_{-\frac{\pi}{\pi}}^{\frac{\pi}{\pi}}d\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}d\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}}\frac{{\int_{-\frac{\pi}{\pi}}^{\frac{\pi}{\pi}}d\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}\pi_{\pi_{\pi_{\pi_{\pi}}}}}^{[1]}}^{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}}}{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}!}\sum_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}}=\int_{\frac{\pi}{\pi}}^{\frac{\pi}{\pi}}d\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}\pi}}^{\int_{-\frac{\pi}{\pi}}^{\frac{\pi}{\pi}}\int_{-\frac{\pi}{\pi}}^{\frac{\pi}{\pi}}d\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}\pi_{\pi}}d\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}\pi_{\pi_{\pi}}}}\frac{{\int_{-\frac{\pi}{\pi}}^{\frac{\pi}{\pi}}d\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}^{1}}^{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}}}}{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}}!}\sum_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}\pi_{\pi_{\pi_{\pi}}}}=\int_{\frac{\pi}{\pi}}^{\frac{\pi}{\pi}}d\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}\pi_{\pi_{\pi_{\pi_{\pi}}}}}}^{\int_{-\frac{\pi}{\pi}}^{\frac{\pi}{\pi}}\int_{-\frac{\pi}{\pi}}^{\frac{\pi}{\pi}}d\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}d\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}}}\frac{{\int_{-\frac{\pi}{\pi}}^{\frac{\pi}{\pi}}d\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}^{0}}^{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}\pi_{\pi_{\pi_{\pi}}}}}}{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}\pi_{\pi_{\pi_{\pi}}}}!}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}}^{-\frac{\pi}{\pi}}d\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}} \right) }}}{\int_{-\frac{\pi}{\pi}}^{\frac{\pi}{\pi}}d\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}}^{-\left( \int_{\frac{\pi}{\pi}}^{{\sum_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}}=\int_{\frac{\pi}{\pi}}^{\frac{\pi}{\pi}}d\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}}}^{\int_{-\frac{\pi}{\pi}}^{\frac{\pi}{\pi}}\int_{-\frac{\pi}{\pi}}^{\frac{\pi}{\pi}}d\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}}d\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}}}}\frac{{\int_{-\frac{\pi}{\pi}}^{\frac{\pi}{\pi}}d\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}}^{[1, 0]}}^{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}}}}{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}}!}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}}\pi}^{-\frac{\pi}{\pi}}d\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}}\pi} \right) }}}{\int_{-\frac{\pi}{\pi}}^{\frac{\pi}{\pi}}d\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}}\pi_{\pi}}^{-\left( \int_{\frac{\pi}{\pi}}^{{\sum_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}}\pi_{\pi_{\pi_{\pi_{\pi}}}}}=\int_{\frac{\pi}{\pi}}^{\frac{\pi}{\pi}}d\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}}^{\int_{-\frac{\pi}{\pi}}^{\frac{\pi}{\pi}}\int_{-\frac{\pi}{\pi}}^{\frac{\pi}{\pi}}d\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}}d\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}}}}\frac{{\int_{-\frac{\pi}{\pi}}^{\frac{\pi}{\pi}}d\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}}\pi_{\pi_{\pi}}}^{[1, 0]}}^{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}}\pi_{\pi_{\pi_{\pi_{\pi}}}}}}}{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}}\pi_{\pi_{\pi_{\pi_{\pi}}}}}!}\sum_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}}}=\int_{\frac{\pi}{\pi}}^{\frac{\pi}{\pi}}d\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}}}}^{\int_{-\frac{\pi}{\pi}}^{\frac{\pi}{\pi}}\int_{-\frac{\pi}{\pi}}^{\frac{\pi}{\pi}}d\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}}}d\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}}}}\frac{{\int_{-\frac{\pi}{\pi}}^{\frac{\pi}{\pi}}d\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}}\pi_{\pi_{\pi_{\pi}}}}^{0}}^{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}}}}}{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}}}!}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}}}^{-\frac{\pi}{\pi}}d\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}}\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi_{\pi}}}}}}}} \right) }}\right)^{-\frac{\pi}{\pi}}$$
