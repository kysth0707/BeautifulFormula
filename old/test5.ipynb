# %% [markdown]
# # testing new method for making squared formula

# %% [markdown]
# $$\frac{a}{b}$$

# %% [markdown]
# $$\frac{\frac{a}{b}}{c}$$

# %% [markdown]
# a/(bc)

# %% [markdown]
# $$\frac{\frac{\frac{a}{b}}{c}}{d}$$

# %% [markdown]
# a/bcd

# %% [markdown]
# $$\frac{a}{\frac{b}{\frac{c}{d}}}$$

# %% [markdown]
# a/ 1 / bd/c
#   ac/bd

# %% [markdown]
# $${\frac{\frac{\frac{1}{b}}{c}}{d}}^{-1}$$

# %% [markdown]
# (1/bcd)-1=bcd

# %%
tmp = "1"
for i in range(1, 5):
	tmp = r"\frac{"+tmp+"}{"+str(i)+"}"
print(tmp+"^{-1}")
# Out:
# \frac{\frac{\frac{\frac{1}{1}}{2}}{3}}{4}^{-1}

# %% [markdown]
# $$\frac{\frac{\frac{\frac{1}{1}}{2}}{3}}{4}^{-1}$$
